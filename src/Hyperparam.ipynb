# %%
import pandas as pd
import numpy as np
from decisiontree import dtree, entropy, gini
from algorithms import predict, metrics, collapseToBin
import warnings
warnings.filterwarnings("ignore")

# %%
# Intialize possible hyperparameters
criterions = [gini, entropy]
max_depths = [i for i in range(1, 25)]
target_impurities = np.arange(20, -1, -2) / 100
min_examples = [i for i in range(8, 2, -1)]

critMap = {gini: "gini", entropy: 'entropy'}


accuracies = []

# %%
df = pd.read_csv("../data/team_data_v4.csv")
df.drop(["Unnamed: 0"], inplace=True, axis=1)
df
# Out:
#                 home_team              away_team  home_shots_prop  \
# 0     Toronto Maple Leafs        Ottawa Senators         0.596154
# 1     Philadelphia Flyers          Boston Bruins         0.467742
# 2     Toronto Maple Leafs        Ottawa Senators         0.450980
# 3         Arizona Coyotes        St. Louis Blues         0.400000
# 4     Pittsburgh Penguins  Columbus Blue Jackets         0.539683
# ...                   ...                    ...              ...
# 1328  Pittsburgh Penguins    Philadelphia Flyers         0.476923
# 1329        Winnipeg Jets      New Jersey Devils         0.450000
# 1330  Toronto Maple Leafs      Detroit Red Wings         0.642857
# 1331    Vancouver Canucks      Los Angeles Kings         0.490196
# 1332       Calgary Flames          Anaheim Ducks         0.640625
#
#       away_shots_prop  home_corsi_prop  away_corsi_prop  home_fenwick_prop  \
# 0            0.384615         0.511111         0.477778           0.567568
# 1            0.516129         0.446429         0.544643           0.425287
# 2            0.529412         0.469388         0.520408           0.493333
# 3            0.500000         0.400000         0.500000           0.400000
# 4            0.444444         0.528000         0.464000           0.549451
# ...               ...              ...              ...                ...
# 1328         0.507692         0.533333         0.458333           0.467391
# 1329         0.533333         0.504425         0.486726           0.423529
# 1330         0.342857         0.544715         0.447154           0.593750
# 1331         0.490196         0.528846         0.461538           0.513514
# 1332         0.343750         0.591667         0.400000           0.670213
#
#       away_fenwick_prop  home_penalties_prop  away_penalties_prop  \
# 0              0.418919             0.375000             0.500000
# 1              0.563218             0.500000             0.450000
# 2              0.493333             0.428571             0.428571
# 3              0.500000             0.000000             0.000000
# 4              0.439560             0.500000             0.375000
# ...                 ...                  ...                  ...
# 1328           0.521739             0.562500             0.375000
# 1329           0.564706             0.375000             0.500000
# 1330           0.395833             0.333333             0.555556
# 1331           0.472973             0.285714             0.571429
# 1332           0.319149             0.250000             0.500000
#
#       home_hits_prop  away_hits_prop  home_takeaways_prop  \
# 0           0.392405        0.594937             0.727273
# 1           0.462687        0.522388             0.500000
# 2           0.397436        0.589744             0.470588
# 3           0.000000        0.000000             0.000000
# 4           0.565789        0.421053             0.625000
# ...              ...             ...                  ...
# 1328        0.483333        0.500000             0.500000
# 1329        0.629630        0.333333             0.562500
# 1330        0.555556        0.425926             0.500000
# 1331        0.465517        0.517241             0.428571
# 1332        0.500000        0.470588             0.352941
#
#       away_takeaways_prop  game_end
# 0                0.181818  home win
# 1                0.428571  home win
# 2                0.470588  away win
# 3                0.000000  away win
# 4                0.312500  home win
# ...                   ...       ...
# 1328             0.461538  home win
# 1329             0.375000  home win
# 1330             0.437500  away win
# 1331             0.428571  away win
# 1332             0.588235  home win
#
# [1333 rows x 15 columns]

# %%
apply = np.vectorize(lambda x: collapseToBin("home win", x))

# %%
# do mini
def validate(data, crit, max_dpth=None, min_inst=2, target_imp=0.0):
    folds = 10
    class_col = data.columns[-1]
    temp_accuracies = []

    for f in range(folds):
        train_fold = data[data.index % folds != f]
        model = dtree(train_fold, crit, class_col, max_dpth, min_inst, target_imp)
        # print("completed training -------")

        valid_fold = data[data.index % folds == f]
        predicts = predict(model, valid_fold)
        predicts = apply(predicts)

        actual = np.array(valid_fold["game_end"])
        actual = apply(actual)
        
        scores = metrics(actual, predicts)
        # print(scores)
        accuracy = scores["accuracy"]
        temp_accuracies.append(accuracy)
    return round(sum(temp_accuracies) / 10, 4)

# %%
def testHyperparams(df):
    bestScore = 0
    bestDepth = max_depths[0]
    bestTarget = target_impurities[0]
    bestMin = min_examples[0]

    for max_depth in max_depths:
        for crit in criterions:
            print(critMap[crit], "| max depth;", max_depth, "| target impurity;", bestTarget, "| minimum instances;",
                  bestMin)
            score = validate(df, crit, max_depth, bestMin, bestTarget)
            if score >= bestScore:
                bestDepth = max_depth
                bestScore = score
            print(score)

    best_score = 0
    for target in target_impurities:
        for crit in criterions:
            print(critMap[crit], "| max depth;", bestDepth, "| target impurity;", target, "| minimum instances;",
                  bestMin)
            score = validate(df, crit, bestDepth, bestMin, target)
            if score >= bestScore:
                bestTarget = target
                bestScore = score
            print(score)

    best_score = 0
    for min_example in min_examples:
        for crit in criterions:
            print(critMap[crit], "| max depth;", bestDepth, "| target impurity;", bestTarget, "| minimum instances;",
                  min_example)
            score = validate(df, crit, bestDepth, min_example, bestTarget)
            if score >= bestScore:
                bestMin = min_example
                bestScore = score
            print(score)
    return bestScore, bestTarget, bestDepth, bestMin

# %%
selected = testHyperparams(df)
print(selected)
# Out:
# gini | max depth; 1 | target impurity; 0.2 | minimum instances; 8
# 0.5544
# entropy | max depth; 1 | target impurity; 0.2 | minimum instances; 8
# 0.5544
# gini | max depth; 2 | target impurity; 0.2 | minimum instances; 8
# 0.5604
# entropy | max depth; 2 | target impurity; 0.2 | minimum instances; 8
# 0.5589
# gini | max depth; 3 | target impurity; 0.2 | minimum instances; 8
# 0.5657
# entropy | max depth; 3 | target impurity; 0.2 | minimum instances; 8
# 0.5702
# gini | max depth; 4 | target impurity; 0.2 | minimum instances; 8
# 0.5972
# entropy | max depth; 4 | target impurity; 0.2 | minimum instances; 8
# 0.5777
# gini | max depth; 5 | target impurity; 0.2 | minimum instances; 8
# 0.5717
# entropy | max depth; 5 | target impurity; 0.2 | minimum instances; 8
# 0.5672
# gini | max depth; 6 | target impurity; 0.2 | minimum instances; 8
# 0.5822
# entropy | max depth; 6 | target impurity; 0.2 | minimum instances; 8
# 0.5792
# gini | max depth; 7 | target impurity; 0.2 | minimum instances; 8
# 0.5626
# entropy | max depth; 7 | target impurity; 0.2 | minimum instances; 8
# 0.5709
# gini | max depth; 8 | target impurity; 0.2 | minimum instances; 8
# 0.5822
# entropy | max depth; 8 | target impurity; 0.2 | minimum instances; 8
# 0.5709
# gini | max depth; 9 | target impurity; 0.2 | minimum instances; 8
# 0.5724
# entropy | max depth; 9 | target impurity; 0.2 | minimum instances; 8
# 0.5686
# gini | max depth; 10 | target impurity; 0.2 | minimum instances; 8
# 0.5732
# entropy | max depth; 10 | target impurity; 0.2 | minimum instances; 8
# 0.5611
# gini | max depth; 11 | target impurity; 0.2 | minimum instances; 8
# 0.5747
# entropy | max depth; 11 | target impurity; 0.2 | minimum instances; 8
# 0.5717
# gini | max depth; 12 | target impurity; 0.2 | minimum instances; 8
# 0.5724
# entropy | max depth; 12 | target impurity; 0.2 | minimum instances; 8
# 0.5716
# gini | max depth; 13 | target impurity; 0.2 | minimum instances; 8
# 0.5732
# entropy | max depth; 13 | target impurity; 0.2 | minimum instances; 8
# 0.5551
# gini | max depth; 14 | target impurity; 0.2 | minimum instances; 8
# 0.5694
# entropy | max depth; 14 | target impurity; 0.2 | minimum instances; 8
# 0.5537
# gini | max depth; 15 | target impurity; 0.2 | minimum instances; 8
# 0.5732
# entropy | max depth; 15 | target impurity; 0.2 | minimum instances; 8
# 0.5634
# gini | max depth; 16 | target impurity; 0.2 | minimum instances; 8
# 0.5739
# entropy | max depth; 16 | target impurity; 0.2 | minimum instances; 8
# 0.5567
# gini | max depth; 17 | target impurity; 0.2 | minimum instances; 8
# 0.5717
# entropy | max depth; 17 | target impurity; 0.2 | minimum instances; 8
# 0.5566
# gini | max depth; 18 | target impurity; 0.2 | minimum instances; 8
# 0.5724
# entropy | max depth; 18 | target impurity; 0.2 | minimum instances; 8
# 0.5566
# gini | max depth; 19 | target impurity; 0.2 | minimum instances; 8
# 0.5709
# entropy | max depth; 19 | target impurity; 0.2 | minimum instances; 8
# 0.5566
# gini | max depth; 20 | target impurity; 0.2 | minimum instances; 8
# 0.5717
# entropy | max depth; 20 | target impurity; 0.2 | minimum instances; 8
# 0.5544
# gini | max depth; 21 | target impurity; 0.2 | minimum instances; 8
# 0.5709
# entropy | max depth; 21 | target impurity; 0.2 | minimum instances; 8
# 0.5552
# gini | max depth; 22 | target impurity; 0.2 | minimum instances; 8
# 0.5702
# entropy | max depth; 22 | target impurity; 0.2 | minimum instances; 8
# 0.5552
# gini | max depth; 23 | target impurity; 0.2 | minimum instances; 8
# 0.5702
# entropy | max depth; 23 | target impurity; 0.2 | minimum instances; 8
# 0.5536
# gini | max depth; 24 | target impurity; 0.2 | minimum instances; 8
# 0.5702
# entropy | max depth; 24 | target impurity; 0.2 | minimum instances; 8
# 0.5544
# gini | max depth; 4 | target impurity; 0.2 | minimum instances; 8
# 0.5972
# entropy | max depth; 4 | target impurity; 0.2 | minimum instances; 8
# 0.5777
# gini | max depth; 4 | target impurity; 0.18 | minimum instances; 8
# 0.598
# entropy | max depth; 4 | target impurity; 0.18 | minimum instances; 8
# 0.5777
# gini | max depth; 4 | target impurity; 0.16 | minimum instances; 8
# 0.598
# entropy | max depth; 4 | target impurity; 0.16 | minimum instances; 8
# 0.5777
# gini | max depth; 4 | target impurity; 0.14 | minimum instances; 8
# 0.598
# entropy | max depth; 4 | target impurity; 0.14 | minimum instances; 8
# 0.5777
# gini | max depth; 4 | target impurity; 0.12 | minimum instances; 8
# 0.598
# entropy | max depth; 4 | target impurity; 0.12 | minimum instances; 8
# 0.5777
# gini | max depth; 4 | target impurity; 0.1 | minimum instances; 8
# 0.598
# entropy | max depth; 4 | target impurity; 0.1 | minimum instances; 8
# 0.5777
# gini | max depth; 4 | target impurity; 0.08 | minimum instances; 8
# 0.598
# entropy | max depth; 4 | target impurity; 0.08 | minimum instances; 8
# 0.5777
# gini | max depth; 4 | target impurity; 0.06 | minimum instances; 8
# 0.598
# entropy | max depth; 4 | target impurity; 0.06 | minimum instances; 8
# 0.5777
# gini | max depth; 4 | target impurity; 0.04 | minimum instances; 8
# 0.598
# entropy | max depth; 4 | target impurity; 0.04 | minimum instances; 8
# 0.5777
# gini | max depth; 4 | target impurity; 0.02 | minimum instances; 8
# 0.598
# entropy | max depth; 4 | target impurity; 0.02 | minimum instances; 8
# 0.5777
# gini | max depth; 4 | target impurity; 0.0 | minimum instances; 8
# 0.598
# entropy | max depth; 4 | target impurity; 0.0 | minimum instances; 8
# 0.5777
# gini | max depth; 4 | target impurity; 0.0 | minimum instances; 8
# 0.598
# entropy | max depth; 4 | target impurity; 0.0 | minimum instances; 8
# 0.5777
# gini | max depth; 4 | target impurity; 0.0 | minimum instances; 7
# 0.598
# entropy | max depth; 4 | target impurity; 0.0 | minimum instances; 7
# 0.5777
# gini | max depth; 4 | target impurity; 0.0 | minimum instances; 6
# 0.598
# entropy | max depth; 4 | target impurity; 0.0 | minimum instances; 6
# 0.5777
# gini | max depth; 4 | target impurity; 0.0 | minimum instances; 5
# 0.598
# entropy | max depth; 4 | target impurity; 0.0 | minimum instances; 5
# 0.5777
# gini | max depth; 4 | target impurity; 0.0 | minimum instances; 4
# 0.598
# entropy | max depth; 4 | target impurity; 0.0 | minimum instances; 4
# 0.5777
# gini | max depth; 4 | target impurity; 0.0 | minimum instances; 3
# 0.598
# entropy | max depth; 4 | target impurity; 0.0 | minimum instances; 3
# 0.5777
# (0.598, 0.0, 4, 3)

# %%
model = dtree(df, gini, list(df.columns)[-1], 10, 3, 0.0)
print(model)
predicts = predict(model, df)
predicts = apply(predicts)

actual = np.array(df["game_end"])
actual = apply(actual)

print(actual)
print(set(predicts))
        
scores = metrics(actual, predicts)
print(scores)
# Out:
# ('away_hits_prop', 0.487, 0       home win
# 1       home win
# 2       away win
# 3       away win
# 4       home win
#           ...
# 1328    home win
# 1329    home win
# 1330    away win
# 1331    away win
# 1332    home win
# Name: game_end, Length: 1333, dtype: object, 'home win', 0.48166654505457474, 0, ('home_takeaways_prop', 0.476, 3       away win
# 4       home win
# 5       away win
# 7       away win
# 8       home win
#           ...
# 1325    away win
# 1327    home win
# 1329    home win
# 1330    away win
# 1332    home win
# Name: game_end, Length: 737, dtype: object, 'away win', 0.4755018955565422, 1, ('away_team', 'Boston Bruins', 3       away win
# 7       away win
# 24      home win
# 26      home win
# 29      away win
#           ...
# 1314    away win
# 1317    away win
# 1318    away win
# 1322    away win
# 1332    home win
# Name: game_end, Length: 300, dtype: object, 'away win', 0.41700000000000004, 2, ('away_penalties_prop', 0.615, 7       away win
# 26      home win
# 79      home win
# 108     home win
# 194     home win
# 277     home win
# 286     away win
# 372     home win
# 388     home win
# 402     home win
# 445     home win
# 483     home win
# 590     away win
# 684     home win
# 917     home win
# 948     home win
# 957     away win
# 1128    home win
# 1144    away win
# 1332    home win
# Name: game_end, dtype: object, 'home win', 0.17647058823529418, 3, (None, None, 7       away win
# 26      home win
# 79      home win
# 108     home win
# 194     home win
# 277     home win
# 286     away win
# 372     home win
# 388     home win
# 402     home win
# 445     home win
# 483     home win
# 684     home win
# 917     home win
# 948     home win
# 1128    home win
# 1332    home win
# Name: game_end, dtype: object, 'home win', 0, 4, None, None), (None, None, 590     away win
# 957     away win
# 1144    away win
# Name: game_end, dtype: object, 'away win', 0, 4, None, None)), ('away_corsi_prop', 0.484, 3       away win
# 24      home win
# 29      away win
# 34      away win
# 35      away win
#           ...
# 1296    home win
# 1314    away win
# 1317    away win
# 1318    away win
# 1322    away win
# Name: game_end, Length: 280, dtype: object, 'away win', 0.40110605074821076, 3, (None, None, 24      home win
# 29      away win
# 35      away win
# 45      away win
# 71      away win
#           ...
# 1247    away win
# 1279    home win
# 1284    home win
# 1296    home win
# 1317    away win
# Name: game_end, Length: 106, dtype: object, 'away win', 0, 4, None, None), (None, None, 3       away win
# 34      away win
# 39      away win
# 49      away win
# 59      away win
#           ...
# 1288    home win
# 1290    home win
# 1314    away win
# 1318    away win
# 1322    away win
# Name: game_end, Length: 174, dtype: object, 'away win', 0, 4, None, None))), ('away_corsi_prop', 0.575, 4       home win
# 5       away win
# 8       home win
# 10      home win
# 11      home win
#           ...
# 1324    away win
# 1325    away win
# 1327    home win
# 1329    home win
# 1330    away win
# Name: game_end, Length: 437, dtype: object, 'home win', 0.4790517582279596, 2, ('home_penalties_prop', 0.357, 4       home win
# 5       away win
# 8       home win
# 10      home win
# 11      home win
#           ...
# 1324    away win
# 1325    away win
# 1327    home win
# 1329    home win
# 1330    away win
# Name: game_end, Length: 407, dtype: object, 'home win', 0.48115738550521153, 3, (None, None, 17      home win
# 27      home win
# 57      home win
# 93      home win
# 127     away win
#           ...
# 1250    away win
# 1295    away win
# 1312    away win
# 1320    away win
# 1330    away win
# Name: game_end, Length: 85, dtype: object, 'away win', 0, 4, None, None), (None, None, 4       home win
# 5       away win
# 8       home win
# 10      home win
# 11      home win
#           ...
# 1321    home win
# 1324    away win
# 1325    away win
# 1327    home win
# 1329    home win
# Name: game_end, Length: 322, dtype: object, 'home win', 0, 4, None, None)), ('away_takeaways_prop', 0.227, 131     away win
# 153     away win
# 179     away win
# 207     away win
# 232     away win
# 379     home win
# 404     away win
# 417     home win
# 437     away win
# 468     away win
# 547     home win
# 599     away win
# 632     away win
# 662     away win
# 672     away win
# 850     away win
# 931     home win
# 971     home win
# 974     away win
# 1024    away win
# 1032    away win
# 1044    away win
# 1086    away win
# 1093    away win
# 1135    away win
# 1259    away win
# 1289    away win
# 1309    away win
# 1310    away win
# 1315    away win
# Name: game_end, dtype: object, 'away win', 0.23602484472049706, 3, (None, None, 379     home win
# 404     away win
# 547     home win
# 632     away win
# 971     home win
# 1309    away win
# 1315    away win
# Name: game_end, dtype: object, 'away win', 0, 4, None, None), (None, None, 131     away win
# 153     away win
# 179     away win
# 207     away win
# 232     away win
# 417     home win
# 437     away win
# 468     away win
# 599     away win
# 662     away win
# 672     away win
# 850     away win
# 931     home win
# 974     away win
# 1024    away win
# 1032    away win
# 1044    away win
# 1086    away win
# 1093    away win
# 1135    away win
# 1259    away win
# 1289    away win
# 1310    away win
# Name: game_end, dtype: object, 'away win', 0, 4, None, None)))), ('away_corsi_prop', 0.458, 0       home win
# 1       home win
# 2       away win
# 6       home win
# 9       away win
#           ...
# 1319    home win
# 1323    home win
# 1326    home win
# 1328    home win
# 1331    away win
# Name: game_end, Length: 596, dtype: object, 'home win', 0.45550425164940694, 1, ('home_fenwick_prop', 0.597, 6       home win
# 12      home win
# 13      home win
# 16      home win
# 20      away win
#           ...
# 1293    away win
# 1300    home win
# 1311    home win
# 1323    home win
# 1326    home win
# Name: game_end, Length: 198, dtype: object, 'home win', 0.36421522402830814, 2, ('home_penalties_prop', 0.417, 6       home win
# 16      home win
# 23      home win
# 31      home win
# 38      home win
#           ...
# 1266    home win
# 1267    home win
# 1293    away win
# 1323    home win
# 1326    home win
# Name: game_end, Length: 107, dtype: object, 'home win', 0.25157179269328805, 3, (None, None, 31      home win
# 101     home win
# 167     home win
# 181     home win
# 253     home win
# 266     home win
# 282     home win
# 284     home win
# 307     away win
# 325     home win
# 337     home win
# 362     away win
# 376     home win
# 392     home win
# 408     away win
# 488     home win
# 499     home win
# 500     home win
# 523     home win
# 534     away win
# 542     home win
# 551     away win
# 555     home win
# 572     away win
# 595     away win
# 597     home win
# 600     home win
# 619     home win
# 633     home win
# 635     home win
# 668     home win
# 674     away win
# 702     home win
# 716     away win
# 750     home win
# 761     home win
# 763     home win
# 765     home win
# 792     away win
# 827     home win
# 843     home win
# 855     home win
# 880     away win
# 886     home win
# 964     away win
# 1092    home win
# 1157    home win
# 1175    home win
# 1193    home win
# 1226    home win
# 1293    away win
# 1326    home win
# Name: game_end, dtype: object, 'home win', 0, 4, None, None), (None, None, 6       home win
# 16      home win
# 23      home win
# 38      home win
# 65      home win
# 100     home win
# 200     home win
# 287     home win
# 288     home win
# 310     home win
# 336     home win
# 348     home win
# 377     home win
# 390     home win
# 431     home win
# 438     home win
# 439     away win
# 448     away win
# 474     home win
# 540     home win
# 559     home win
# 562     home win
# 569     home win
# 609     home win
# 689     home win
# 739     home win
# 784     home win
# 785     home win
# 848     home win
# 873     home win
# 887     home win
# 895     home win
# 900     home win
# 902     home win
# 903     home win
# 942     away win
# 960     home win
# 966     home win
# 982     home win
# 1003    home win
# 1048    home win
# 1065    home win
# 1100    away win
# 1107    home win
# 1149    home win
# 1150    home win
# 1160    home win
# 1182    home win
# 1216    home win
# 1246    home win
# 1257    home win
# 1261    home win
# 1266    home win
# 1267    home win
# 1323    home win
# Name: game_end, dtype: object, 'home win', 0, 4, None, None)), ('home_corsi_prop', 0.552, 12      home win
# 13      home win
# 20      away win
# 25      home win
# 51      home win
#           ...
# 1241    home win
# 1276    home win
# 1286    away win
# 1300    home win
# 1311    home win
# Name: game_end, Length: 91, dtype: object, 'home win', 0.4247893028380833, 3, (None, None, 51      home win
# 134     away win
# 226     away win
# 290     away win
# 329     away win
# 340     away win
# 724     away win
# 753     away win
# 1062    away win
# Name: game_end, dtype: object, 'away win', 0, 4, None, None), (None, None, 12      home win
# 13      home win
# 20      away win
# 25      home win
# 54      home win
#           ...
# 1241    home win
# 1276    home win
# 1286    away win
# 1300    home win
# 1311    home win
# Name: game_end, Length: 82, dtype: object, 'home win', 0, 4, None, None))), ('home_takeaways_prop', 0.579, 0       home win
# 1       home win
# 2       away win
# 9       away win
# 15      away win
#           ...
# 1308    home win
# 1316    home win
# 1319    home win
# 1328    home win
# 1331    away win
# Name: game_end, Length: 398, dtype: object, 'home win', 0.4755011520546513, 2, ('home_penalties_prop', 0.4, 1       home win
# 2       away win
# 9       away win
# 15      away win
# 18      away win
#           ...
# 1308    home win
# 1316    home win
# 1319    home win
# 1328    home win
# 1331    away win
# Name: game_end, Length: 287, dtype: object, 'home win', 0.48826050620180417, 3, (None, None, 18      away win
# 21      away win
# 42      away win
# 53      away win
# 56      home win
#           ...
# 1278    away win
# 1303    away win
# 1307    home win
# 1308    home win
# 1331    away win
# Name: game_end, Length: 110, dtype: object, 'away win', 0, 4, None, None), (None, None, 1       home win
# 2       away win
# 9       away win
# 15      away win
# 28      away win
#           ...
# 1297    away win
# 1298    home win
# 1316    home win
# 1319    home win
# 1328    home win
# Name: game_end, Length: 177, dtype: object, 'home win', 0, 4, None, None)), ('away_team', 'Calgary Flames', 0       home win
# 47      home win
# 52      home win
# 67      home win
# 73      home win
#           ...
# 1217    home win
# 1230    away win
# 1242    home win
# 1263    away win
# 1291    away win
# Name: game_end, Length: 111, dtype: object, 'home win', 0.3770829653182595, 3, (None, None, 67      home win
# 228     away win
# 334     away win
# 558     home win
# 573     away win
# 660     away win
# 816     away win
# 1034    away win
# 1203    away win
# Name: game_end, dtype: object, 'away win', 0, 4, None, None), (None, None, 0       home win
# 47      home win
# 52      home win
# 73      home win
# 75      home win
#           ...
# 1217    home win
# 1230    away win
# 1242    home win
# 1263    away win
# 1291    away win
# Name: game_end, Length: 102, dtype: object, 'home win', 0, 4, None, None)))))
# [0 0 1 ... 1 1 0]
# {0, 1}
# {'accuracy': 0.6616654163540885, 'sensitivity': 0.5598086124401914, 'specificity': 0.7521246458923513, 'precision': 0.6673003802281369, 'f1-score': 0.6088464874241111}

# %%
def testHyperparams2(df):
    bestScore = 0
    for max_depth in max_depths:
        for crit in criterions:
            print(critMap[crit], "| max depth;", max_depth, "| target impurity;", 0.0, "| minimum instances;",
                  3)
            score = validate(df, crit, max_depth, 3, 0.0)
            if score >= bestScore:
                bestDepth = max_depth
                bestScore = score
            print(score)

# %%
testHyperparams2(df)
# Out:
# gini | max depth; 1 | target impurity; 0.0 | minimum instances; 3
# 0.5544
# entropy | max depth; 1 | target impurity; 0.0 | minimum instances; 3
# 0.5544
# gini | max depth; 2 | target impurity; 0.0 | minimum instances; 3
# 0.5604
# entropy | max depth; 2 | target impurity; 0.0 | minimum instances; 3
# 0.5589
# gini | max depth; 3 | target impurity; 0.0 | minimum instances; 3
# 0.5657
# entropy | max depth; 3 | target impurity; 0.0 | minimum instances; 3
# 0.5702
# gini | max depth; 4 | target impurity; 0.0 | minimum instances; 3
# 0.598
# entropy | max depth; 4 | target impurity; 0.0 | minimum instances; 3
# 0.5777
# gini | max depth; 5 | target impurity; 0.0 | minimum instances; 3
# 0.5717
# entropy | max depth; 5 | target impurity; 0.0 | minimum instances; 3
# 0.5672
# gini | max depth; 6 | target impurity; 0.0 | minimum instances; 3
# 0.5837
# entropy | max depth; 6 | target impurity; 0.0 | minimum instances; 3
# 0.5792
# gini | max depth; 7 | target impurity; 0.0 | minimum instances; 3
# 0.5604
# entropy | max depth; 7 | target impurity; 0.0 | minimum instances; 3
# 0.5709
# gini | max depth; 8 | target impurity; 0.0 | minimum instances; 3
# 0.5762
# entropy | max depth; 8 | target impurity; 0.0 | minimum instances; 3
# 0.5724
# gini | max depth; 9 | target impurity; 0.0 | minimum instances; 3
# 0.5627
# entropy | max depth; 9 | target impurity; 0.0 | minimum instances; 3
# 0.5694
# gini | max depth; 10 | target impurity; 0.0 | minimum instances; 3
# 0.5582
# entropy | max depth; 10 | target impurity; 0.0 | minimum instances; 3
# 0.5596
# gini | max depth; 11 | target impurity; 0.0 | minimum instances; 3
# 0.5567
# entropy | max depth; 11 | target impurity; 0.0 | minimum instances; 3
# 0.5694
# gini | max depth; 12 | target impurity; 0.0 | minimum instances; 3
# 0.5537
# entropy | max depth; 12 | target impurity; 0.0 | minimum instances; 3
# 0.5657
# gini | max depth; 13 | target impurity; 0.0 | minimum instances; 3
# 0.5529
# entropy | max depth; 13 | target impurity; 0.0 | minimum instances; 3
# 0.5462
# gini | max depth; 14 | target impurity; 0.0 | minimum instances; 3
# 0.5484
# entropy | max depth; 14 | target impurity; 0.0 | minimum instances; 3
# 0.5454
# gini | max depth; 15 | target impurity; 0.0 | minimum instances; 3
# 0.5537
# entropy | max depth; 15 | target impurity; 0.0 | minimum instances; 3
# 0.5544
# gini | max depth; 16 | target impurity; 0.0 | minimum instances; 3
# 0.5544
# entropy | max depth; 16 | target impurity; 0.0 | minimum instances; 3
# 0.5477
# gini | max depth; 17 | target impurity; 0.0 | minimum instances; 3
# 0.5522
# entropy | max depth; 17 | target impurity; 0.0 | minimum instances; 3
# 0.5484
# gini | max depth; 18 | target impurity; 0.0 | minimum instances; 3
# 0.553
# entropy | max depth; 18 | target impurity; 0.0 | minimum instances; 3
# 0.5492
# gini | max depth; 19 | target impurity; 0.0 | minimum instances; 3
# 0.5507
# entropy | max depth; 19 | target impurity; 0.0 | minimum instances; 3
# 0.5492
# gini | max depth; 20 | target impurity; 0.0 | minimum instances; 3
# 0.5514
# entropy | max depth; 20 | target impurity; 0.0 | minimum instances; 3
# 0.5477
# gini | max depth; 21 | target impurity; 0.0 | minimum instances; 3
# 0.5507
# entropy | max depth; 21 | target impurity; 0.0 | minimum instances; 3
# 0.5484
# gini | max depth; 22 | target impurity; 0.0 | minimum instances; 3
# 0.5499
# entropy | max depth; 22 | target impurity; 0.0 | minimum instances; 3
# 0.5477
# gini | max depth; 23 | target impurity; 0.0 | minimum instances; 3
# 0.5499
# entropy | max depth; 23 | target impurity; 0.0 | minimum instances; 3
# 0.5469
# gini | max depth; 24 | target impurity; 0.0 | minimum instances; 3
# 0.5499
# entropy | max depth; 24 | target impurity; 0.0 | minimum instances; 3
# 0.5477
